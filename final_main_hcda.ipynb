# %% [markdown]
# <a href="https://colab.research.google.com/github/Marie1009/PIR/blob/master/final_main_hcda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import os
os.chdir("/content/gdrive/My Drive/PIR/Reconnaissance et Apprentissage de Chroniques")
# !ls
# Out:
# 'Anciens fichiers .ipynb'		  main_final.py
#  ccdc_final.py				  main_upgrade.py
#  CCDC.ipynb				  __pycache__
#  ccdc.py				 'suivi travail.gdoc'
#  CCDC_sliding.ipynb			  test_dataset_HCDA.ipynb
#  ccdc_upgrade.py			  test_main.ipynb
#  datasetP				  test_main_marie.ipynb
#  Fichiers				  test_main_upgrade.ipynb
#  final_main.ipynb			 'test_sans_py -- V4_HCDA.ipynb'
#  HCDA.ipynb				  Untitled0.ipynb
#  hcda.py				  v4_hcda_final.py
#  HCDA_tester.ipynb			  V4_HCDA.ipynb
#  hcda_tester.py				  v4_hcda.py
#  HCDAtoWinepi.ipynb			  v4_hcda_upgrade.py
# 'Historique versions HCDA fonctionnels'

# %%
import ccdc_final
import v4_hcda_final

import time

# Debut du decompte du temps
start_time = time.time()

# recuperation des datasets
all_data = v4_hcda_final.get_sequences("./datasetP")
print('get_sequences')
# modification des timestamps sans concatenation des sequences (division par 1000 de toutes les valeurs)
data_modif = v4_hcda_final.modif_timestamps(all_data,0.001)
print('modif_timestamps')

# choix du nombre de sequences a analyser
nb_salades = 10
data_selected = data_modif[0:nb_salades]
#concatenation et decalage des timestamps
transformed_data= v4_hcda_final.decal_concat(data_selected)
print('decal_concat')
#for d in transformed_data:
#    print(d)

limite_ecarts = v4_hcda_final.exploration(data_selected)
limite_freq = nb_salades #au minimum on veut que les chroniques soient presentes 1 fois par salade... mais pas verifiable

gaps_dict = {}
for E in data_selected:
    ccdc_final.get_gaps(E, limite_ecarts, gaps_dict)
base = ccdc_final.generate_trees(gaps_dict)
#ccdc.print_tree(base)

#base = ccdc.CCDC(transformed_data,limite_ecarts)
#ccdc.print_tree(base)

results = v4_hcda_final.main_concat_v2(limite_ecarts,limite_freq,base,transformed_data)
#results = v4_hcda_final.main_concat(limite_ecarts,limite_freq,lambda x: ccdc_final.CCDC(x,limite_ecarts),transformed_data)

#avec indice
#results = v4_hcda_final.main_concat(limite_ecarts,limite_freq,lambda x: ccdc_final.CCDC(x,limite_ecarts),transformed_data[:v4_hcda.indice(nb_salades,all_data)])

# Affichage du temps d execution
print("Temps d execution : %s secondes ---" % (time.time() - start_time))

print(len(results))
# Out:
# base :
# ('A', 'B')
# [-2, 1]
# [-2, 0][-1, 1]
# [-2, -1][-1, 0][0, 1]
# base :
# ('A', 'C')
# [-2, 2]
# [-2, 1][-1, 2]
# [-2, -1][-1, 1][1, 2]
# base :
# ('B', 'C')
# [-2, 3]
# [-2, 1][0, 3]
# [-2, 0][0, 1][1, 3]
# get_sequences
# modif_timestamps
# timestamp le plus grand : 448893
# ecart min entre timestamps : 200
# ecart max entre timestamps : 76477
# 448893
# decal_concat
# timestamp le plus grand : 448893
# ecart min entre timestamps : 200
# ecart max entre timestamps : 76477
# time constraint    events                                                              frequence  occurences
# -----------------  ----------------------------------------------------------------  -----------  ------------------------------------------------------------------------------------------------------------------------
# ...
